# %% [markdown]
# <a href="https://colab.research.google.com/github/Sajeenafiza/EDA-Capstone-project/blob/main/new_of_Copy_of_mine_EDA_Submission_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Hotel Booking Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### Project done by: Sajeena T R

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The main aim of this project is to perform an Explaratory Data Analysis on hotel booking analysis which investigates the different booking patterns and the customer behaviour and suggests measures that can be  implemented to increase the revenue.
#
#    The project contains booking information for a city hotel and resort hotel, such as the booking date, month,year,customer information such as number of adults, children and babies.As the first step I explored the data and inspected over the duplicate values and the missing values.Then I cleaned the dataset by handling the null values and dropping the duplicate values and irrelevant data.Then it was visualized using the graphical techniques.
#
#    EDA is divided into univariate, bivariate and multi variate analysis.  In univariate, data is analysed on only one variable. For example, the most preferred hotel by the customers, the busiest month, the year with most number of bookings etc.
#
#  In bivariate and mutivariate two or more than two variables are compared with each other.For example, the hotel with the highest number of cancellations are taking place, the month in which most cancellations are taking place, the number of repeated guests for each hotel etc.
#
#   From these analysis we can take measures to reduce the number of cancellations and to improve the customer service. By taking these measures we can make a revenue increase.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data.
# Explore and analyse the data to discover important factors that govern the bookings.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The project aims to gain the interesting insight into the different factors that affect the booking patterns and cancellations and to take measures  to enhance the quality and customer satisfaction, thus by increasing the revenue.

# %% [markdown]
# ### Types of graph used

# %% [markdown]
# * Pie chart
# * Histogram
# * Count plot
# * Bar plot
# * Line plot
# * Scatter plot
# * Heat map
# * Pair plot

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Read dataset
hotel_df=pd.read_csv('drive/My Drive/EDA/Hotel Bookings.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
hotel_df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
# Dataset last 5 rows
hotel_df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
hotel_df.shape
# Out:
# (119390, 32)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
hotel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
# dataset numerical details
hotel_df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
# creating a copy of dataset
hoteldf=hotel_df.copy()
hoteldf.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
# last 5 rows
hoteldf.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
# displaying the dataset columns
hoteldf.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# converting the datatype from string to datetime
hoteldf['reservation_status_date']=pd.to_datetime(hoteldf['reservation_status_date'])

# %%
# Dataset Info
hoteldf.info()
# data type of reservation_status_date converted to datetime
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count

print(len(hoteldf[hoteldf.duplicated()]))

# printing  the duplicate values
dup=hoteldf[hoteldf.duplicated()]
dup.head(5)
# Out:
# 31994
#             hotel  is_canceled  lead_time  arrival_date_year  \
# 5    Resort Hotel            0         14               2015
# 22   Resort Hotel            0         72               2015
# 43   Resort Hotel            0         70               2015
# 138  Resort Hotel            1          5               2015
# 200  Resort Hotel            0          0               2015
#
#     arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 5                 July                        27                          1
# 22                July                        27                          1
# 43                July                        27                          2
# 138               July                        28                          5
# 200               July                        28                          7
#
#      stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# ...

# %%
# drop the duplicates
hoteldf.drop_duplicates(inplace=True)

# dropped the duplicates.Now the duplicate count is 0
print(len(hoteldf[hoteldf.duplicated()]))
# Out:
# 0

# %%
# Dataset Rows & Columns count
hoteldf.shape
# Out:
# (87396, 32)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count

print(hoteldf.isnull().sum())
print("Total number of null values are",len(hoteldf.isnull()))
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              4
# babies                                0
# meal                                  0
# country                             452
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# ...

# %%
# Visualizing the missing values
plt.rcParams['figure.figsize'] = (12, 7)
sns.heatmap(hoteldf.isnull(),cmap='coolwarm')
plt.title('Missing Values')
# Out:
# Text(0.5, 1.0, 'Missing Values')

# %% [markdown]
# ###The columns children,agent,company and country have the missing values.

# %% [markdown]
# ## Filling the missing values

# %%
# finding the unique values for children column
hoteldf['children'].unique()
# Out:
# array([ 0.,  1.,  2., 10.,  3., nan])

# %%
# checking the mode of children column
hoteldf['children'].mode()
# Out:
# 0    0.0
# Name: children, dtype: float64

# %%
# Filling the missing value with mode as the children column is categorical and the values are discrete
hoteldf['children'].fillna(hoteldf['children'].mode()[0],inplace=True)

# %%
# filling the missing value with '0' for the columns agent and company
hoteldf['agent'].fillna('0',inplace=True)

hoteldf['company'].fillna('0',inplace=True)

# filling the missing value with 'others' for the column country

hoteldf['country'].fillna('others',inplace=True)

# %%
# checking for null values
hoteldf.isnull().sum()

# All the null values are removed
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset contains 119390 rows and  32 columns.It contains 31994 duplicate values.After dropping the duplicate values the columns are reduced to 87396.Total number of null values in the dataset is  87396.The columns children contains 4, country contains 452, agent contains 12193 and company contains 82137 null values.All the missing values are removed using the values '0' and 'others'.Thus the dataset is cleaned and ready for wrangling.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
hoteldf.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
hoteldf.describe()
# Out:
#         is_canceled     lead_time  arrival_date_year  \
# count  87396.000000  87396.000000       87396.000000
# mean       0.274898     79.891368        2016.210296
# std        0.446466     86.052325           0.686102
# min        0.000000      0.000000        2015.000000
# 25%        0.000000     11.000000        2016.000000
# 50%        0.000000     49.000000        2016.000000
# 75%        1.000000    125.000000        2017.000000
# max        1.000000    737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              87396.000000               87396.000000
# mean                  26.838334                  15.815541
# std                   13.674572                   8.835146
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   27.000000                  16.000000
# 75%                   37.000000                  23.000000
# ...

# %% [markdown]
# ###categorical values
# hotel,arrival_date_month,meal,country, agent, company, market_segment, distribution_channel, reserved_room_type,
#        assigned_room_type,customer_type,reservation_status, reservation_status_date,  deposit_type
# ###numerical values
# is_canceled, lead_time, arrival_date_year,
#         arrival_date_week_number,
#        arrival_date_day_of_month, stays_in_weekend_nights,
#        stays_in_week_nights, adults, children, babies,
#        is_repeated_guest, previous_cancellations,
#        previous_bookings_not_canceled,
#      booking_changes,
#         days_in_waiting_list,  adr,
#        required_car_parking_spaces, total_of_special_requests

# %% [markdown]
# ### Variables Description

# %% [markdown]
#  Hotel	--> H1= Resort Hotel ,H2=City Hotel
#
# is_cancelled -->	       If the booking was cancelled(1) or not(O)
#
# lead_time	-->Number of days that elapsed between the entering date of the
#            booking into the PMS and the arrival date
#
# arrival_date_year-->Year of arrival date
#
# arrival_date_month-->Month of arrival date
#
# arrival_date_week_number-->	Week number for arrival date
#
# arrival_dat_day	-->Day of arrival date
#
# stays_in_weekend_nights-->Number of weekend nights (Saturday or Sunday) the
#               guest stayed or booked to stay at the hotel
#
# stays_in_week_nights-->	Number of week nights (Monday to Friday) the guest stayed
#              or booked to stay at the hotel
#
# adults-->Number of adults
#
# children-->Number of children
#
# babies-->	Number of babies
#
# meal-->Kind of meal opted for
#
# country-->	Country code
#
# market_segment-->Which segment the customer belongs to
#
# Distribution _channel-->	How the customer accessed the stay- corporate  booking/
#                      Direct/TA.TO
#
# is_repeated_guest-->Guest coming for first time or not
#
# previous_cancellation-->	Was there a cancellation before
#
# previous_bookings	-->Count of previous bookings
#
# reserved_room_type-->	Type of room reserved
#
# assigned_room_type-->	Type of room assigned
#
# booking_changes-->	Count of changes made to booking
#
# deposit_type-->	Deposit type
#
# agent	-->Booked through agent
#
# days_in_waiting_list-->	Number of days in waiting list
#
# customer_type-->Type of customer
#
# required_car_parking-->If car parking is required
#
# total_of_special_req-->	Number of additional special requirements
#
# reservation_status-->Reservation of status
#
# reservation_status_date-->Date of the specific status

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.

for i in hoteldf.columns.tolist():
  print("No. of unique values in ",i,":",hoteldf[i].nunique(), "\n the values are:    ",hoteldf[i].unique())
# Out:
# No. of unique values in  hotel : 2
#  the values are:     ['Resort Hotel' 'City Hotel']
# No. of unique values in  is_canceled : 2
#  the values are:     [0 1]
# No. of unique values in  lead_time : 479
#  the values are:     [342 737   7  13  14   0   9  85  75  23  35  68  18  37  12  72 127  78
#   48  60  77  99 118  95  96  69  45  40  15  36  43  70  16 107  47 113
#   90  50  93  76   3   1  10   5  17  51  71  63  62 101   2  81 368 364
#  324  79  21 109 102   4  98  92  26  73 115  86  52  29  30  33  32   8
#  100  44  80  97  64  39  34  27  82  94 110 111  84  66 104  28 258 112
#   65  67  55  88  54 292  83 105 280 394  24 103 366 249  22  91  11 108
#  106  31  87  41 304 117  59  53  58 116  42 321  38  56  49 317   6  57
#   19  25 315 123  46  89  61 312 299 130  74 298 119  20 286 136 129 124
#  327 131 460 140 114 139 122 137 126 120 128 135 150 143 151 132 125 157
#  147 138 156 164 346 159 160 161 333 381 149 154 297 163 314 155 323 340
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# checking for adult column with 0.If so we can drop those columns

# converting children column from float to int
hoteldf['children']=hoteldf['children'].astype(int)
hoteldf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87396 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87396 non-null  object
#  1   is_canceled                     87396 non-null  int64
#  2   lead_time                       87396 non-null  int64
#  3   arrival_date_year               87396 non-null  int64
#  4   arrival_date_month              87396 non-null  object
#  5   arrival_date_week_number        87396 non-null  int64
#  6   arrival_date_day_of_month       87396 non-null  int64
#  7   stays_in_weekend_nights         87396 non-null  int64
#  8   stays_in_week_nights            87396 non-null  int64
#  9   adults                          87396 non-null  int64
#  10  children                        87396 non-null  int64
#  11  babies                          87396 non-null  int64
# ...

# %%
# checking for adult column with 0.If so we can drop those columns

hoteldf.drop(hoteldf[hoteldf['adults']==0].index,inplace=True)

# checking the number of rows and columns after dropping
hoteldf.shape
# Out:
# (87011, 32)

# %%
# checking if any negative value for average daily rate
hoteldf[hoteldf['adr']<0]
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 14969  Resort Hotel            0        195               2017
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 14969              March                        10                          5
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 14969                        4                     6       2  ...
#
#        deposit_type  agent company days_in_waiting_list    customer_type  \
# 14969    No Deposit  273.0       0                    0  Transient-Party
#
#         adr  required_car_parking_spaces  total_of_special_requests  \
# 14969 -6.38                            0                          0
#
#        reservation_status reservation_status_date
# 14969           Check-Out              2017-03-15
#
# [1 rows x 32 columns]

# %%
# dropping the column with avrage daily rate -6.38
hoteldf.drop(hoteldf[hoteldf['adr']<0].index,inplace=True)

# checking the number of rows and columns after dropping
hoteldf.shape
# Out:
# (87010, 32)

# %%
# adding one column 'total_people' by adding the number of adults, children and babies
hoteldf['total_people']=hoteldf['adults']+hoteldf['children']+hoteldf['babies']

# adding one column 'total_stay' by adding  the number of stays in weekend nights and week nights
hoteldf['total_stay']=hoteldf['stays_in_weekend_nights']+hoteldf['stays_in_week_nights']

# checking the number of rows and columns after adding
hoteldf.shape
# Out:
# (87010, 34)

# %%
# Found one outlier in adr column

plt.figure(figsize=(12,6))

sns.scatterplot(y = 'adr', x = 'total_stay', data =hoteldf)
# Out:
# <Axes: xlabel='total_stay', ylabel='adr'>

# %%
# removing the outlier

hoteldf.drop(hoteldf[hoteldf['adr'] > 5000].index,inplace=True) #removing the adr having value >5000

# %%
# plotting the graph with outlier removed

plt.figure(figsize=(12,6))

sns.scatterplot(y = 'adr', x = 'total_stay', data =hoteldf)
# Out:
# <Axes: xlabel='total_stay', ylabel='adr'>

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Created a copy of the dataset and dropped all the duplicate values and missing values. We checked if any adult column having value  '0'.Adult 0 means no booking has been happened. So we can drop those columns.Then we checked if any column with  negative value for average daily rate. Negative value for average daily rate is not possible.So that column also dropped. Then we add two more columns 'total_people' by adding adults, children and babies and 'total_stay' by adding  the number of stays in weekend nights and week nights.
#
#  Also one outlier found in adr column, which was then removed.
#
# After all manipulations the total number of rows and columns became 87010 and 34
#
# We got the following insights about the dataset:
# 1. There are two types of hotels, city and resort.
# 2. Customers can book the hotel directly or through diffrent distribution     channels.
# 3. Customers can reserve the room types they want.
# 4. They can opt the meal type.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ###Univariate analysis

# %% [markdown]
# #### Chart - 1
# ###Busiest and slowest month for hotels

# %%
# Chart - 1 visualization code

# Busiest month and slowest month for all hotels
# using the count plot

sns.countplot(x=hoteldf['arrival_date_month'],hue=hoteldf['hotel'])

# Setting the title
plt.title("Busiest and slowest month for hotels",fontsize=22)
plt.xlabel("Month",fontsize=18)
# Out:
# Text(0.5, 0, 'Month')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Count plot is used here.The countplot is used to represent the occurrence(counts) of the observation present in the categorical variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# August is the busiest month for City and resort hotel.
#
# January is the slowest month for City and resort hotel.
#
# Also the customers vist is more on the months of April,May,June and July for city hotels.In the case of resort hotel the busier months are July, April and May.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From this insight hotels can make the necessary arrangements for the customers on the month of August.Also they can provide special offers on the months of November,December and  January which are the slowest months.
#
# There is no insight that leads to negative growth.

# %% [markdown]
# #### Chart - 2
# ###Most preferred hotel

# %%
# Chart - 2 visualization code
# Most preferred hotel

hoteldf['hotel'].value_counts().plot.pie(fontsize=18, autopct='%.0f%%')

# Setting the title
plt.title("Most preferred hotel",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Most preferred hotel')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie chart is used to represent the specific categories that compose the whole.Here it shows the percentage of customers who liked the different types of hotels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# City hotel is the most preferred hotel for all types of customers.61% customers preferred city hotel and 39% preferred resort hotel

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insight we get is that the city hotel is making more revenue rather than resort hotel. Resort hotels can improve their customer services to attract more customers.No negative insights.

# %% [markdown]
# #### Chart - 3
# ###In which year most bookings happened for each type of hotels?

# %%
# Chart - 3 visualization code

# Year with highest booking

sns.countplot(x=hoteldf['arrival_date_year'],hue=hoteldf['hotel'])

# Giving the title

plt.title("Year with highest booking for each type of hotels",fontsize=22)

plt.xlabel("Year",fontsize=18)
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The countplot is used to represent the occurrence(counts) of the observation present in the categorical variable.Here the number of bookings is counted for each year.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In 2016 most bookingshappened  for City and resort hotel.
#
# In 2015 less bookings happened  for City and resort hotel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  In 2016 both the hotels generated large revenue.But in 2017 the number of bookings decreased.Hotels can conduct more promotional events.

# %% [markdown]
# #### Chart - 4
# ##Which agent made the most number of bookings?

# %%
# Chart - 4 visualization code
# Top 5 Agents
# dataframe is grouped by agent and then sorted in descending order to get the top 5 agents.

top_agent=hoteldf.groupby(['agent'])['agent'].agg({'count'}).reset_index().rename(columns={'count':"No. of bookings"}).sort_values('No. of bookings',ascending=False).head()

# plotting using pie chart

keys=top_agent['agent'].unique()
data=top_agent["No. of bookings"].unique()
explode = [0.03,0,0.1,0,0]
plt.pie(data,labels=keys,autopct='%.0f%%',explode=explode)

# Setting the title
plt.title("Top 5 Agents",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Top 5 Agents')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie chart is used to represent the specific categories that compose the whole.Here it shows the percentage of bookings made by the agents.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Agent with agent ID 9 is the one  who made the most number of bookings, followed by agent 240 and agent 0

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Agent with ID 9 helped to increase in the revenue of hotels. So hotels can offer him  gifts or incentives, so that he can make more bookings thus by increasing the revenue of hotels.Also it will be a motivation to other agents.

# %% [markdown]
# #### Chart - 5
# ## Which type of meal is the most preferred  by the customers?

# %%
# Chart - 5 visualization code
# type of food mostly preferred by guests

meals=hoteldf['meal'].unique()
mcount=hoteldf['meal'].value_counts()

newmeals=pd.DataFrame(meals,mcount).reset_index().rename(columns={0:'meals','meal':'mealcount'})

# plotting the bar graph

sns.barplot(y=newmeals['mealcount'],x=newmeals['meals'])

# Setting the title
plt.title('Most preferred type of meal',fontsize=20)
plt.xlabel('Meals')
# Out:
# Text(0.5, 0, 'Meals')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are useful to compare different categorical or discrete variables.Here Categorical variable meal type is compared with the count.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most preferred meal type is BB(Bed & Breakfast), followed by FB(Full Board) and HB(Half Board)

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# As BB is the most preferred meal type the hotels can include different varieties of breakfast. So the customers can order more BB  and this leads to increase in revenue.

# %% [markdown]
# #### Chart - 6
# ##Booking cancellation percentage

# %%
# Chart - 6 visualization code
# Booking cancellation percentage

hoteldf['is_canceled'].value_counts().plot.pie(fontsize=18, autopct='%.0f%%')

# Setting the title
plt.title("Booking cancellation percentage ",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Booking cancellation percentage ')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie chart is used to represent the specific categories that compose the whole.Here it shows the percentage of booking cancellations by the customers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  cancellation =0 means  booking not cancelled
#
#  cancellation =1 means  booking  cancelled
#  From this chart we can understand that only 28% booking is cancelled.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The graph clearly says that booking cancellations are low. But 28% of cancellations are taking place.From this insight we can set a cancellation policy inorder to reduce the cancellation. Also the hotels can provide the option to reschedule the bookings.

# %% [markdown]
# #### Chart - 7
# ##Distribution of customer type for each hotel

# %%
# Chart - 7 visualization code
# distribution of customer type with countplot

sns.countplot(x=hoteldf['customer_type'],hue=hoteldf['hotel'])

# Setting the title

plt.title(" Distribution of customer type for each hotel",fontsize=20)
plt.xlabel("Customer type")
# Out:
# Text(0.5, 0, 'Customer type')

# %%
# distribution of customer type with histogram
sns.histplot(x='customer_type',data=hoteldf,hue=hoteldf['hotel'])

# Setting the title
plt.title(" Distribution of customer type for each hotel",fontsize=20)
plt.xlabel("Customer type")
# Out:
# Text(0.5, 0, 'Customer type')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The countplot is used to represent the occurrence(counts) of the observation present in the categorical variable.Here the number of customers is counted for each customer type.
#
# Also histogram is used for plotting. A histogram is a classic visualization tool that represents the distribution of one or more variables by counting the number of observations that fall within discrete bins.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From these plottings we can make the insights that majority of the customers are Transient, followed by Transient-Party for both city and resort hotels.Minority is the customers in Group.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# As the minority is the Group type,if we provide any special offer for the groups, then that will attract them. That will reflect in the hotel revenue.

# %% [markdown]
# #### Chart - 8
# ##From which country the most customers are coming?

# %%
# Chart - 8 visualization code
#From which country the most guests are coming

top_country=hoteldf.groupby(['country'])['country'].agg({'count'}).reset_index().rename(columns={'count':"No.visitors"}).sort_values('No.visitors',ascending=False).head()

# plotting the graph
keys=top_country['country'].unique()
data=top_country["No.visitors"].unique()
explode = [0.03,0,0.1,0,0]

plt.pie(data,labels=keys,autopct='%.0f%%',explode=explode)

# Setting the title
plt.title("Top 5 countries on the basis of customers",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Top 5 countries on the basis of customers')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie chart is used to represent the specific categories that compose the whole.Here it shows the percentage of customers coming from different countries.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From this plot we  can see, majority of customers from Portugal.
# It shows top 5 countries on the basis of customers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insight is positive. Because the majority of customers are from Portugal, the hotels can include more Portugese dishes and that results in revenue increase.

# %% [markdown]
# #### Chart - 9
# ##Whether the customers are repeatedly coming or not?

# %%
# Chart - 9 visualization code
# Percentage of repeated guests

hoteldf['is_repeated_guest'].value_counts().plot.pie(fontsize=18, autopct='%.0f%%')

# Setting the title
plt.title("Percentage of Repeated guests",fontsize=20)
# repeated guests are very low in percentage
# Out:
# Text(0.5, 1.0, 'Percentage of Repeated guests')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie chart is used to represent the specific categories that compose the whole.Here it shows the percentage of repeated customers.
# 0- Not a repeated guest
# 1- Repeated guest

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Only 4% of customers are revisiting the hotels. 96% customers are new.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insight leads to negative growth.
# The customers are not choosing the same hotels again. The hotels can give more promotional offers and and special offers that can attract them.Also improve the facilities.

# %% [markdown]
# #### Chart - 10
# ##Which is the most preferred room type for different types of customers?

# %%
# Chart - 10 visualization code
# Most preferred room type

sns.countplot(x=hoteldf['reserved_room_type'],hue=hoteldf['customer_type'])

# Setting the title
plt.title("Most preferred room type",fontsize=20)
plt.xlabel('Room type')
# Out:
# Text(0.5, 0, 'Room type')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The countplot is used to represent the occurrence(counts) of the observation present in the categorical variable.This plot shows the count of preferred room type.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 'A' room type is most preferred by all types of customers, followed by D and E.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Gained insight is positive.To increase the revenue, increase the number of 'A' room types. Also add more facilities to 'D', 'E', 'G' and 'F' room types.

# %% [markdown]
# #### Chart - 11
# ## Whether the customer got the reserved room type?

# %%
# Chart - 11 visualization code
# Most assigned room type

sns.countplot(x=hoteldf['assigned_room_type'],hue=hoteldf['customer_type'])

# Setting the title
plt.title("Most assigned room type",fontsize=20)
plt.xlabel('Room type')
# Most assigned room type is A for all the customers
#almost 45000 people reserved for the A room type but assigned only for 40000 people.So increase the number of A type room
# Out:
# Text(0.5, 0, 'Room type')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The countplot is used to represent the occurrence(counts) of the observation present in the categorical variable.This plot shows the count of assigned room type.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From chart 10 we can assume that almost 45000 people reserved for the A  type room. From chart 11 we can see that only 40000 people got the reserved rooms.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The negative insight we got is almost 5000 people didn't get the reserved room type.This may be the one reason for the decrease in the count of repeated customers.So increase the number of A type rooms and improve the facilities.

# %% [markdown]
# #### Chart - 12
# ## Which is the most used distribution channel for booking?

# %%
# Chart - 12 visualization code
# Most preferred distribution channel for booking

plt.figure(figsize=(12,12)) #setting the graph size

channel=hoteldf['distribution_channel'].value_counts().reset_index().rename(columns={'index':'distribution_channel','distribution_channel':'channel_count'})

keys=channel['distribution_channel'].unique()
explode = [0.03,0,0.1,0,0]

plt.pie(channel['channel_count'],labels=keys,autopct='%.0f%%',explode=explode)

# Setting the title
plt.title("Most preferred distribution channel for booking",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Most preferred distribution channel for booking')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie chart is used to represent the specific categories that compose the whole.Here it shows the percentage of distribution channel used for booking.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# TA/TO (Travel Agent/Tour Opeartor)is the most popular distribution channel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# 79% of booking has been done through TA/TO. Make more promotions for corporate and direct distribution channels.

# %% [markdown]
# # Bivariate and multivariate analysis

# %% [markdown]
# ####Chart -13
# ###Hotel with the highest revenue

# %%
# Chart - 13 visualization code
# Categorical -Numerical

# hotel with the highest revenue

highrev=hoteldf.groupby(['hotel'])['adr'].mean().reset_index()

sns.barplot(x=highrev['hotel'],y=highrev['adr'])

# Setting the title
plt.title("Hotel with the highest revenue",fontsize=20)
plt.xlabel('Hotel')
# Out:
# Text(0.5, 0, 'Hotel')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are useful to compare different categorical or discrete variables.Here Categorical variable hotel  is compared with the Average Daily Rate(adr).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Hotel with the highest revenue is city hotel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Can improve the services of resort hotel and can increase the revenue.

# %% [markdown]
# #### Chart - 14
# ### Most profittable month for each hotel

# %%
# Chart - 14 visualization code
# Categorical -Numerical

# adr in different months

highm=hoteldf.groupby(['hotel','arrival_date_month'])['adr'].mean().reset_index()

# setting the months in categorical order
months=['January', 'February', 'March', 'April', 'May', 'June','July', 'August', 'September', 'October', 'November', 'December']
highm['arrival_date_month']=pd.Categorical(highm['arrival_date_month'], categories=months, ordered=True)

sns.lineplot(x=highm['arrival_date_month'],y=highm['adr'],hue=highm['hotel'])

# Setting the title
plt.title("High revenue month for each hotel",fontsize=20)
plt.xlabel('Month')
plt.ylabel('Average Daily Rate')
# Out:
# Text(0, 0.5, 'Average Daily Rate')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A line chart is a type of chart used to show information that changes over time.
# This graph shows the relationship between average daily rate and month.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above graph we can understand that most revenue is generated in the month of August for Resort hotel. For city hotels, most revenue is generated in the month of May and August.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Offer customers with Seasonal  offers, thus can attract more customers.

# %% [markdown]
# #### Chart - 15
# ### Hotel with the highest lead time

# %%
# highest lead time
# Categorical -Numerical

lead=hoteldf.groupby(['hotel'])['lead_time'].mean().reset_index()

sns.barplot(x=lead['hotel'],y=lead['lead_time'])

# Setting the title
plt.title("Highest lead time for each hotel",fontsize=20)
plt.xlabel('Hotel')
plt.ylabel('Lead time')
# Out:
# Text(0, 0.5, 'Lead time')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are useful to compare different categorical or discrete variables.Here Categorical variable hotel is compared with the numerical variable lead time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Resort hotel has the highest lead time compared to city hotel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Lead Time is the period of time between when a guest makes the reservation and the actual check-in/arrival date.A longer lead time can help you anticipate revenues and optimise resource costs. This is because each department in your hotel has enough notice to prepare for a guest's arrival.With the high lead time we can avoid a supply delay, which could negatively affect customer satisfaction.
#
# Also there is a an insight which leads to neagative growth. if the lead time increases, threre is a high chance of cancellation. So give a discount for the confirmed bookings.

# %% [markdown]
# ####Chart -16
# ### Which hotel has the history of high number of booking cancellation?

# %%
# hotel with the highest number of booking cancellation
# Categorical -Numerical

# creating a df with only cancelled bookings
cancel=hoteldf[hoteldf['is_canceled']==1]
can=cancel.groupby(['hotel']).size().reset_index().rename(columns={0:'cancelcount'})

sns.barplot(x=can['hotel'],y=can['cancelcount'])

# Setting the title
plt.title("Hotel with the highest number of booking cancellation",fontsize=20)
plt.xlabel('Hotel')
plt.ylabel('Count of cancellation')
# Out:
# Text(0, 0.5, 'Count of cancellation')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are useful to compare different categorical or discrete variables.Here Categorical variable hotel is compared with the count of cancellations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# City hotel has the history of high number of booking cancellations compared to resort hotels.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# And when a hotel is faced with a last minute cancellation and then a last-minute check-in, the hotel can't do much but sell the room at a much lower price, so there goes the opportunity to earn a higher revenue.
#
# The Hotels can set  cancellation policies by offering the  hotel guests the opportunity to cancel their booking up until a certain amount of days before check-in. Once this date has passed, the hotel might charge the guest a cancellation fee, a percentage of the booking, or the full amount.
# Thus can compensate the loss.

# %% [markdown]
# #### Chart-17
# ### In which month most cancellations take place?

# %%
# month in which most cancellation takes palce

mon=cancel.groupby(['hotel','arrival_date_month']).size().reset_index().rename(columns={0:'countcan'})

sns.barplot(x=mon['arrival_date_month'],y=mon['countcan'],hue=mon['hotel'])

# Setting the title
plt.title("Month with the  most cancellations",fontsize=20)
plt.xlabel('Month')
plt.ylabel('Count of cancellation')
# Out:
# Text(0, 0.5, 'Count of cancellation')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are useful to compare different categorical or discrete variables.Here Categorical variable month is compared with the count of cancellations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The most cancellations takes place in the month of August for both city and resort hotels followed by April, May and July.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# In order to avoid the last minute cancellations Implement a cancellation policy or   give discount for confirmed bookings.

# %% [markdown]
# ####Chart -18
# ###Which hotel has the history of most repeated customers?

# %%
# hotel with the most repeated guests

rept=hoteldf[hoteldf['is_repeated_guest']==1].groupby('hotel')['is_repeated_guest'].size().reset_index()

sns.barplot(x=rept['hotel'],y=rept['is_repeated_guest'])

# Setting the title
plt.title("Hotel with the most repeated guests",fontsize=20)
plt.xlabel('Hotel')
plt.ylabel('No. of repeated guests')
# Out:
# Text(0, 0.5, 'No. of repeated guests')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are useful to compare different categorical or discrete variables.Here Categorical variable Hotel is compared with the number of repeated guests.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most customers  tend to stay in the resort  hotel regularly compared to city hotel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# To increase the number of repeated guests, hotels can do the following:
# 1.Reward repeat customers.
# 2.Act on customer feedback.
# 3.Focus on customer service.

# %% [markdown]
# #### Chart - 19
# ###Which distribution channel generates more income?

# %%
# distribution channel with highest adr
dis=hoteldf.groupby('distribution_channel')['adr'].mean().reset_index()

sns.barplot(x=dis['distribution_channel'],y=dis['adr'])

# Setting the title
plt.title("Distribution channel with highest adr",fontsize=20)
plt.xlabel('Distribution channel')
plt.ylabel('Average Daily Rate')
# Out:
# Text(0, 0.5, 'Average Daily Rate')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are useful to compare different categorical or discrete variables.Here Categorical variable Distribution channel is compared with the Avarage Daily Rate.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# GDS(Global Distribution Systems) is the disribution channel with highest adr, followed by Direct and TA/TO.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The above graph shows that major bookings are through GDS(Global Distribution Systems). Hotels can do some more promotional offers throgh social medias, by which the booking number can be increased through the direct channel.

# %% [markdown]
# #### Chart- 20
# ###Which market segment generates more income?

# %%
# Market segment with highest adr
mar=hoteldf.groupby('market_segment')['adr'].mean().reset_index()

sns.barplot(x=mar['market_segment'],y=mar['adr'])

# Setting the title
plt.title("Market segment with highest adr",fontsize=20)
plt.xlabel('Market segment')
plt.ylabel('Average Daily Rate')
mar
# Out:
#   market_segment         adr
# 0       Aviation  100.613628
# 1  Complementary    3.102573
# 2      Corporate   68.344298
# 3         Direct  116.950454
# 4         Groups   75.184371
# 5  Offline TA/TO   81.962400
# 6      Online TA  118.401641
# 7      Undefined   15.000000

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are useful to compare different categorical or discrete variables.Here Categorical variablemarket segment is compared with the Average Daily Rate.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The most bookings are done through Online TA(Online Travel Agent), followed by Direct and Aviation

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Hotels can offer incentives to Online Tour operators to increase the number of bookings.

# %% [markdown]
# #### Chart - 21
# ###How long people stay in hotels?

# %%
# Optimal stay length
# Numerical-Numerical

# Grouping df by the not cancelled customers
dfcan=hoteldf[hoteldf['is_canceled']==0]


st=dfcan.groupby(['hotel','total_stay']).agg('count').reset_index().rename(columns={'is_canceled':'Staycount'})

sns.barplot(x=st['total_stay'],y=st['Staycount'],hue=st['hotel'])

# Setting the title
plt.title("Number of days",fontsize=20)
plt.xlabel('Hotel')
plt.ylabel('Stay count')
# Out:
# Text(0, 0.5, 'Stay count')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are useful to compare different categorical or discrete variables.Here Total number of stay is  compared with the stay count.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the graph it is clear that most people stayed not more than 3 days.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# To increase the stay length, hotels can offer holiday packages and can conduct more promotional events.

# %% [markdown]
# #### Chart -22
# ###Which hotel has longer waiting time?

# %%
# hotel with longer waiting time

wait=hoteldf.groupby(['hotel'])['days_in_waiting_list'].mean().reset_index()

sns.barplot(x=wait['hotel'],y=wait['days_in_waiting_list'])

# Setting the title
plt.title("Hotel with longer waiting time",fontsize=20)
plt.xlabel('Hotel')
plt.ylabel('Mean waiting time')
# Out:
# Text(0, 0.5, 'Mean waiting time')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are useful to compare different categorical or discrete variables.Here the categorical variable hotel is  compared with the waiting time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# City hotel has the longer waiting time compared to resort hotel. From this it is clear that city hotel is busier than resort hotel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# City hotel is the busier hotel, this is the positive insight. Resort hotel must improve their quality of customer services to avoid the negative growth.
# Also the insight which leads to negative growth is ,as the days in waiting list increases there  is a chance of cancellation. So increse the number of rooms in city hotels.

# %% [markdown]
# #### Chart -23
# ### How is average daily rate related to total number of people?

# %%
# relation between adr and total people
# Numerical-Numerical

ad=hoteldf.groupby('total_people')['adr'].mean().reset_index()

sns.scatterplot(x=ad['adr'],y=ad['total_people'])

# Setting the title
plt.title("Relation between adr and total people",fontsize=20)
plt.xlabel('adr')
plt.ylabel('Total people')
# Out:
# Text(0, 0.5, 'Total people')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We can use scatter plots to explore the relationship between two variables. This graph shows the realtionship between average daily rate and total number of people.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# When the number of people increases the adr also increases, result in increase in revenue.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insight is positive business impact as it increases the revenue.

# %% [markdown]
# #### Chart -24
# ### How many solo travellers, couple or family travelled  per month?

# %%
#  no. of solo travellers, couple and family

#  df which contains the not cancelled customers

dfcan

# df for solo travellers
solo=dfcan[(dfcan['adults']==1) & (dfcan['children']==0) & (dfcan['babies']==0)]

# df for couple
couple=dfcan[(dfcan['adults']==2) & (dfcan['children']==0) & (dfcan['babies']==0)]

# df for family
family=dfcan[dfcan['adults']+dfcan['children']+dfcan['babies']>2]

family
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 13      Resort Hotel            0         18               2015
# 37      Resort Hotel            0         36               2015
# 55      Resort Hotel            0          1               2015
# 65      Resort Hotel            0         10               2015
# 79      Resort Hotel            0         81               2015
# ...              ...          ...        ...                ...
# 119335    City Hotel            0         63               2017
# 119339    City Hotel            0        110               2017
# 119376    City Hotel            0        165               2017
# 119382    City Hotel            0        135               2017
# 119386    City Hotel            0        102               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 13                   July                        27
# 37                   July                        27
# ...

# %%
# months in categorical order
months=['January', 'February', 'March', 'April', 'May', 'June','July', 'August', 'September', 'October', 'November', 'December']

# looping to find the number of solo, couple and family
for i in ['solo','couple','family']:
 final=eval(i).groupby('arrival_date_month').size().reset_index().rename(columns={0:'peoplecount'})
 final['arrival_date_month']=pd.Categorical(final['arrival_date_month'], categories=months, ordered=True)

 sns.lineplot(x=final['arrival_date_month'],y=final['peoplecount'],label=i)

# Setting the title
 plt.title("No. of couple or family per month",fontsize=20)
 plt.xlabel('Month')
 plt.ylabel('No. of people')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Line chart is used to show the number of solo travellers, couple or family visited per month.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In the month of August most customers are couples.
# In July and August most of the customers are family.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insight is positive business impact as  we can see an  increase in the number of customers in the months of July and August. Hotels can offer more offer packages for couple and family.

# %% [markdown]
# #### Chart - 25 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

plt.rcParams['figure.figsize'] = (20, 15) # graph size

sns.heatmap(hoteldf.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Heat map is used to show the corelation between different variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **There is a positive corelation between is_canceled and days_in_waitinglist.if the number of days in waiting list is more there is a chance of cancellation.
#
# **Positive corelation between leadtime and is_canceled. if the leadtime increases there is a high chance of cancellation.
#
# Also there is a strong relation between leadtime and total stay.
#
# ** Negative corelation between is_repeated guest and adr.If the adr is high then the number of repeated guests will be low.
#
# Positive corelation between is_repeated guest and required_carparking_space.
# Guests are repeatedly visiting because of the number of carparking space is high.
#
# ** Positive corelation between adr and totalstay.If totalstay increases adr also increases.
#
# Also there is a very strong relation between adr and total people.If the number of  total people is high then adr will also be high.
#
# Again there is a positive relation between adr and booking_changes.If the adr is high there is a chance of booking change.
#
# **Positive corelation between totalof_special_requests and total_stay. If the special request guest is there, then  there is  a chance of high number of total stay.
#
# Also a strong negative relation between totalof_special_requests and is_repeated guests.Special request guests are not choosing the same hotel again.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

sns.pairplot(hoteldf,hue='hotel')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pair plot allows to plot  pairwise relationships between variables within a dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There is a positive corelation between adults and totalpeople.
#
# Positive corelation between laedtime and totalstay.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# 1.   August and July are the most income generating months. January, November and December are the slowest months for both hotels.Concentrate on  group business such as intimate wedding or family reunions by giving special offers on these slowest months.
# 2. Most preferred hotel by the customers is city.Resort hotel must improve the customer services and offer holiday packages.
# 3. In 2017 the number of bookings decreased for both city and resort hotels.Do more promotional events.
# 4. Agent with ID 9 is the one who made most number of bookings.Offer him extra incentive, sothat other agents can  also work hard to increase the number of bookings.
# 5. Majority of the customers opted the BB(Bed&Breakfast) meal type. Include more items in the breakfast menu.
# 6. 28% customers cancelled the bookings.Implement any cancellation policy    cancellation policies by offering the  hotel guests the opportunity to cancel their booking up until a certain amount of days before check-in. Once this date has passed, the hotel might charge the guest a cancellation fee, a percentage of the booking, or the full amount.Thus can compensate the loss. decrease the Also the hotels can provide the option to reschedule the bookings.
# 7. Most number of cancellations takes place in City hotels on the month of August.
# 8. Majority of the customers visited  is Transient type.Offer a discount package for Group type customers.
# 9. The majority of the customers from the country Portugal. Include more Portugese dishes in the menu.
# 10. Only 4% customers are repeated guests. The customers are not opting the same hotel for the second time. Improve the customer service and hospitality.
# 11. Most repeated customers opted for resort hotel.
# 12. Almost 45000 customers reserved the room type 'A. But only 40000 assigned the same. This may be one reason for increase in the number of booking cancellations.So increase the number of room type 'A'.
# 13. Highest income generated distribution channel is GDS and the market segment is online TA(Online Travel Agent).Make more promotions through other channels also.
# 14. City hotel is busier than resort hotel. So increase the number of rooms and add more facilities in the city hotel.
# 15. When the number of total people increases, the average daily rate also increases. So provide special offer for Group type customers.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# *  61% customers preferred city hotels. 39% customers preferred resort hotels.
# * August and July are the most income generating months. January, November and
#   December are the slowest months for both hotels
# * Highest number of bookings are made in the year 2016.Least number of
#   bookings are done in 2015.
# * Most income generating agent is 9 followed by 240 and 0.
# * Most preferred meal type is BB(Bed & Breakfast)
# * 72% customers not cancelled the booking.28% customers cancelled the bookings.
# * Majority of the customers are Transient, followed by Transient-Party for both
#   city and resort hotels.Minority is the customers in Group.
# * Majority of the customers from Portugal.
# * 96% customers new customers. Only 4% is the repeated customers.
# * Most customers preferred the 'A' type room.
# * Most customers got the 'A' type room.
# * Most number of bookings are done through the GDS distribution channel.So the
#   most income generated distribution channel is GDS.
# * Higher revenue generated  hotel is city, compared to resort hotel.
# * Most profittable month for Resort hotel is August and for city hotel is May and August.
# * Resort hotel has higher lead time comapared to city hotel.
# * Most number of booking cancellations are in  city hotels.
# * Most number of cancellations take place in the month of August.
# * Repeated customers mostly prefer the resort hotels.
# * Most revenue generated market segment is Online TA.
# * City hotel is busier than resort hotel.
# * Most people stayed not more than 3 days.
# * When the number of people increases the adr also increases.
# * In the month of August most customers are couples. In July and August most   of  the customers are family.
# * There is a positive corelation between is_canceled and days_in_waitinglist.
# * There is a strong negative relation between totalof_special_requests and
#  is_repeated guest.
# * Negative corelation between is_repeated guest and adr

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
